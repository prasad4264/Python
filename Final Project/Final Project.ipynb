# %%
import json
import re
class Restuarnt:
    def __init__(self):
        self.food_items = {}
        self.user_to_see = {}
        self.food_id = len(self.food_items)+1
        print("   -------------------------------------Welcome to our Restuarnt-------------------------------------------  ")
        print("                                                                                                             ")
    def items(self):
        number_of_items = int(input("Enter number of items to add : "))
        for i in range(1,number_of_items+1):
            self.name = input("Enter item Name : ")
            self.quantity = int(input("Enter number of qantity in pieces or kg : "))
            self.price = int(input("Enter the price of item in Rupees : "))
            self.discount = int(input("Enter the discount in Rupees : "))
            self.stock = int(input("Enter how much stock left : "))
            self.list = {"Name" : self.name,"Quantity":self.quantity,"Price":self.price,"Discount":self.discount,"Stock":self.stock}
            self.food_id = len(self.food_items)+1
            self.food_items[self.food_id] = self.list
            self.user_list = {"Name" : self.name,"Quantity":self.quantity,"Price":self.price}
            self.user_to_see[self.food_id] = self.user_list
        with open ("admin_list.json","w") as f:
            json.dump(self.food_items,f)
        with open ("user_list.json","w") as d:
            json.dump(self.user_to_see,d)
        print(self.food_items)
    def edit_items(self):
        x = int(input("Enter food id that you want to update : \n"))
        if x in self.food_items.keys():
            print("1. Update food name\n2. update quantity\n3. update price\n4. update discount\n5. update stock")
            y = input("Enter the key that you want edit : ")
            if y == "1":
                self.food_items[x]["Name"] = input("Enter your new food name : ")
                print("\n Successfully Updated \n")
            elif y == "2":
                self.food_items[x]["Quantity"] = float(input("Enter updated quantity : "))
                print("\n Successfully Updated \n")
            elif y == "3":
                self.food_items[x]["Price"] = int(input("Enter updated price : "))
                print("\n Successfully Updated \n")
            elif y == "4":
                self.food_items[x]["Discount"] = int(input("Enter the updated discount : "))
                print("\n Successfully Updated \n")
            elif y == "5":
                self.food_items[x]["Stock"] = int(input("Enter updated stock : "))
                print("\n Successfully Updated \n")
            else:
                print("Invalid option")
        else:
            print("Incorrect food id")
    def add(self):
        number_of_items = int(input("Enter number of items to add : "))
        for i in range(1,number_of_items+1):
            self.name = input("Enter item Name : ")
            self.quantity = int(input("Enter number of qantity in pieces : "))
            self.price = int(input("Enter the price of item in Rupees : "))
            self.discount = int(input("Enter the discount in Rupees : "))
            self.stock = int(input("Enter how much stock left : "))
            self.list = {"Name" : self.name,"Quantity":self.quantity,"Price":self.price,"Discount":self.discount,"Stock":self.stock}
            self.food_id = len(self.food_items)+1
            self.food_items[self.food_id] = self.list
        with open ("admin_list.json","w+") as f:
            json.dump(self.food_items,f)
        print(self.food_items)
    def remove(self):
        item_id = int(input("Enter your item number to remove : "))
        del self.food_items[item_id]
        print(self.food_items)
class user(Exception):
    def __init__(self):
        self.user_details = {}
        self.personal = {}
        self.update = {}
        print("     -------------------------------------user--------------------------------------------------       ")
    def registration(self):
        self.name = input("Enter your name : ")
        mobile_no=input("Enter your Number : ")
        m=re.fullmatch("[6-9][0-9]{9}",mobile_no)
        if m!=None:
            print("Valid Mobile Number")
            self.mobile_no = mobile_no
            Email_id = input("Enter Your Mail Id : ")
            matcher = re.finditer("@",Email_id)
            y = 0
            for i in matcher:
                y=i.start()
            if Email_id[y+1:]=="gmail.com":
                print("It is a gmail Id")
                self.mail_id = Email_id
                self.address = input("Enter your Address : ")
                self.password = input("Enter your Password : ")
                self.user_details = {"Name":self.name,"Mobile no":self.mobile_no,"Mailid":self.mail_id,"Address":self.address,"Password":self.password}
                self.personal = {"Mobile no":self.mobile_no,"Password":self.password}
                print("user details updated successfully ")
        else :
            print("invalid number")
    def log_in(self):
        phone_number = int(input("Enter your number to login : "))
        password = input("Enter your Password to login : ")
        if phone_number == self.mobile_no:
            if password == self.password:
                print("Login successfull")
            else:
                print("invalid password")
    def menu(self):
        print("1 . Place Your Order")
        print("2 . Order History")
        print("3 . Update Profile")
        n = int(input("Enter your option : "))
        if n <= 0:
            print("Enter valid option ")
        elif n == 1:
            print("Place your order")
            with open ("user_list.json","r") as f:
                x = json.load(f)
            c = list(x.values())
            for i in c:
                print(i)
            with open ("user_list.json","r") as d:
                x = json.load(d)
            n = [int(i) for i in input().split(",")]
            for j in x.keys():
                a = int(j)
                if a in n:
                    print(x[j])
                    u = x[j]
                    self.order_id = len(self.update)+1
                    self.update[self.order_id] = u
                    print("The items you ordered ", self.update)
            with open ("oder_history.json","w+") as f:
                json.dump(self.update,f)
        elif n == 2:
            print("order_history")
            with open ("oder_history.json","r") as f:
                a = json.load(f)
            d = list(a.values())
            for j in d:
                print(j)
        else:
            print("Enter valid input")
    def update_profile(self):
        print("1. edit full_name\n2. edit mobile_no\n3. edit email_id\n4. edit address\n5. password\n6. exit")
        y=int(input("select your option "))
        if y==1:
            self.user_details["Name"]=input("enter your new name ")
            print("DONE ")
        elif y==2:
            self.user_details["Mobile_no"]=int(input("enter your new mobile no "))
            print("DONE")
        elif y==3:
            self.user_details["Mail_id"]=input("enter your new email_id ")
            print("DONE")
        elif y==4:
            self.user_details["Address"]=input("enter your new address ")
            print("DONE ")
        elif y==5:
            self.user_details["Password"]=input("enter your new password ")
            print("DONE ")
        elif y==6:
            break
        else:
            print("Enter valid number")
r = Restuarnt()
r.items()
r.add()
r.edit_items()
r.remove()
c = user()
c.registration()
c.log_in()
c.menu()
c.menu()
c.update_profile()
# Out:
#    -------------------------------------Welcome to our Restuarnt-------------------------------------------
#
# Enter number of items to add : 3
# Enter item Name : Tandoori
# Enter number of qantity in pieces or kg : 4
# Enter the price of item in Rupees : 240
# Enter the discount in Rupees : 20
# Enter how much stock left : 2
# Enter item Name : Burger
# Enter number of qantity in pieces or kg : 2
# Enter the price of item in Rupees : 100
# Enter the discount in Rupees : 20
# Enter how much stock left : 2
# Enter item Name : Cake
# Enter number of qantity in pieces or kg : 2
# Enter the price of item in Rupees : 100
# Enter the discount in Rupees : 10
# Enter how much stock left : 3
# {1: {'Name': 'Tandoori', 'Quantity': 4, 'Price': 240, 'Discount': 20, 'Stock': 2}, 2: {'Name': 'Burger', 'Quantity': 2, 'Price': 100, 'Discount': 20, 'Stock': 2}, 3: {'Name': 'Cake', 'Quantity': 2, 'Price': 100, 'Discount': 10, 'Stock': 3}}
# Enter number of items to add : 1
# ...
